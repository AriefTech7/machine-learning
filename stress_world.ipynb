# %%
import pandas as pd

# %%
# mendownload dataset dari kaggle
df = pd.read_csv(r"C:\Users\user\Documents\machine-learning\Data\academic Stress level - maintainance 1.csv")

# %%
df.sample(5)
# Out:
#                Timestamp Your Academic Stage  Peer pressure  \
# 109  26/07/2025 10:39:37         high school              2
# 85   25/07/2025 17:51:17       post-graduate              4
# 48   24/07/2025 22:39:36       undergraduate              3
# 64   24/07/2025 23:44:35       undergraduate              3
# 66   25/07/2025 00:13:46       undergraduate              4
#
#      Academic pressure from your home Study Environment  \
# 109                                 4          Peaceful
# 85                                  4             Noisy
# 48                                  4             Noisy
# 64                                  2          Peaceful
# 66                                  3          Peaceful
#
#             What coping strategy you use as a student?  \
# 109                 Emotional breakdown (crying a lot)
# 85   Analyze the situation and handle it with intel...
# 48                  Emotional breakdown (crying a lot)
# ...

# %%
tipedata_col = df.dtypes
df.describe()
# Out:
#        Peer pressure  Academic pressure from your home  \
# count     140.000000                        140.000000
# mean        3.071429                          3.178571
# std         1.083844                          1.276618
# min         1.000000                          1.000000
# 25%         2.000000                          2.000000
# 50%         3.000000                          3.000000
# 75%         4.000000                          4.000000
# max         5.000000                          5.000000
#
#        What would you rate the academic  competition in your student life  \
# count                                         140.000000
# mean                                            3.492857
# std                                             1.028349
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                              0
# Your Academic Stage                                                    0
# Peer pressure                                                          0
# Academic pressure from your home                                       0
# Study Environment                                                      1
# What coping strategy you use as a student?                             0
# Do you have any bad habits like smoking, drinking on a daily basis?    0
# What would you rate the academic  competition in your student life     0
# Rate your academic stress index                                        0
# dtype: int64

# %%
df['Study Environment'] = df['Study Environment'].fillna("Tidak Diketahui")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(4)
# Out:
#                Timestamp Your Academic Stage  Peer pressure  \
# 92   26/07/2025 07:25:43         high school              4
# 103  26/07/2025 09:36:09         high school              1
# 94   26/07/2025 07:34:28         high school              4
# 63   24/07/2025 23:36:22       undergraduate              3
#
#      Academic pressure from your home Study Environment  \
# 92                                  5          Peaceful
# 103                                 3          Peaceful
# 94                                  5             Noisy
# 63                                  3         disrupted
#
#             What coping strategy you use as a student?  \
# 92   Analyze the situation and handle it with intel...
# 103                   Social support (friends, family)
# 94                  Emotional breakdown (crying a lot)
# 63   Analyze the situation and handle it with intel...
#
#     Do you have any bad habits like smoking, drinking on a daily basis?  \
# ...

# %%
tekanan_dirumah = df.groupby('Your Academic Stage')['Academic pressure from your home'].agg(['mean', 'median', 'std', 'prod', 'sum'])
