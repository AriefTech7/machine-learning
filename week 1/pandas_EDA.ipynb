# %% [markdown]
# EDA(eksploratory data analysis)

# %%
import pandas as pd

# %%
dataframe = pd.read_csv(r'C:\Users\user\Documents\machine-learning\Data\hotel_bookings.csv')

# %%
dataframe
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df_shape = pd.DataFrame([dataframe.shape], columns=['jumlah baris', 'jumlah kolom'])
df_shape
# Out:
#    jumlah baris  jumlah kolom
# 0        119390            32

# %%
dataframe.shape
# Out:
# (119390, 32)

# %% [markdown]
# function .head(parameter) -> dipandas untuk melihat data paling atas

# %%
dataframe.head(11)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                July                        27                          1
# 1                July                        27                          1
# ...

# %% [markdown]
# function .tail(parameter) -> membaca data dari bawah pada pandas

# %%
dataframe.tail(11)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119379  City Hotel            0        109               2017
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119379             August                        35
# 119380             August                        35
# 119381             August                        35
# ...

# %% [markdown]
# function .sample() -> mencari sample

# %%
dataframe.sample()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 61556  City Hotel            1        185               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 61556           December                        51                         16
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 61556                        1                     2       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 61556    No Deposit    9.0     NaN                    0     Transient  79.2
#
#        required_car_parking_spaces  total_of_special_requests  \
# 61556                            0                          0
#
#        reservation_status reservation_status_date
# 61556            Canceled              2016-07-28
#
# [1 rows x 32 columns]

# %% [markdown]
# .colom -> menampilkan colom saja  pada dataframe

# %%
dataframe.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df_colom = pd.DataFrame(dataframe.columns, columns=['nama kolom'])
df_colom
# Out:
#                         nama kolom
# 0                            hotel
# 1                      is_canceled
# 2                        lead_time
# 3                arrival_date_year
# 4               arrival_date_month
# 5         arrival_date_week_number
# 6        arrival_date_day_of_month
# 7          stays_in_weekend_nights
# 8             stays_in_week_nights
# 9                           adults
# 10                        children
# 11                          babies
# 12                            meal
# 13                         country
# 14                  market_segment
# 15            distribution_channel
# 16               is_repeated_guest
# 17          previous_cancellations
# 18  previous_bookings_not_canceled
# 19              reserved_room_type
# 20              assigned_room_type
# 21                 booking_changes
# 22                    deposit_type
# 23                           agent
# 24                         company
# 25            days_in_waiting_list
# ...

# %% [markdown]
# .dtypes -> untuk melihat tipe data pada suatu data

# %%
dataframe.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
pd.DataFrame(dataframe.dtypes, columns=['Tipe data']).reset_index().rename(columns={'index':'name colom'})
# Out:
#                         name colom Tipe data
# 0                            hotel    object
# 1                      is_canceled     int64
# 2                        lead_time     int64
# 3                arrival_date_year     int64
# 4               arrival_date_month    object
# 5         arrival_date_week_number     int64
# 6        arrival_date_day_of_month     int64
# 7          stays_in_weekend_nights     int64
# 8             stays_in_week_nights     int64
# 9                           adults     int64
# 10                        children   float64
# 11                          babies     int64
# 12                            meal    object
# 13                         country    object
# 14                  market_segment    object
# 15            distribution_channel    object
# 16               is_repeated_guest     int64
# 17          previous_cancellations     int64
# 18  previous_bookings_not_canceled     int64
# 19              reserved_room_type    object
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# .describe() -> menghasilkan kolom statistik

# %%
#describe
dataframe.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ## DATA CLEANING
# handle missing value

# %%
dataframe.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# mencari data kosong dan mengonversinya menjadi persentase

# %%
dataframe.isnull().sum() / len(dataframe) *100
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %% [markdown]
# salah satu cara untuk mengisi missing value

# %%
dataframe['country'] = dataframe['country'].fillna('unknown')

# %%
dataframe.isnull().sum() / len(dataframe) *100
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.000000
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %%
dataframe['children'] = dataframe['children'].fillna(0)

# %%
dataframe.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
dataframe['agent'] = dataframe['agent'].fillna(0)

# %%
dataframe.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# kenapa colom company dihapus karena sebagian besar datanya kosong 
# syarat untuk menghapus colom yaitu data yang kosong > 50%
dataframenew = dataframe.drop(columns=['company'], axis=1)
dataframenew
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
dataframenew.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %% [markdown]
# duplicate data

# %%
dataframenew.duplicated().sum()
# Out:
# np.int64(32001)

# %%
dataframenew[dataframenew.duplicated()].head(5)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 5    Resort Hotel            0         14               2015
# 22   Resort Hotel            0         72               2015
# 43   Resort Hotel            0         70               2015
# 138  Resort Hotel            1          5               2015
# 200  Resort Hotel            0          0               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 5                 July                        27                          1
# 22                July                        27                          1
# 43                July                        27                          2
# 138               July                        28                          5
# 200               July                        28                          7
#
#      stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 5                          0                     2       2  ...
# ...

# %%
dataframenew_drop_duplicate = dataframenew.drop_duplicates()

# %%
dataframenew_drop_duplicate.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %% [markdown]
# # aggregation & feature engineering

# %% [markdown]
# ### aggregation

# %%
dataframenew_drop_duplicate.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 108791    City Hotel            0         75               2017
# 20579   Resort Hotel            0          0               2016
# 113630    City Hotel            0         30               2017
# 38176   Resort Hotel            0          4               2017
# 91570     City Hotel            0         92               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 108791              March                        13
# 20579            February                         8
# 113630               June                        23
# 38176                July                        28
# 91570                June                        26
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 108791                         29                        0
# 20579                          18                        0
# 113630                          6                        0
# ...

# %%
# .groupby()
# .unstack() -> merapikan data(untuk beberapa hal saja yg unstack bisa digunakan)
# .value_counts() -> Menghitung jumlah kemunculan digunakan diaggregation dan harus memiliki 2 feature
dataframenew_drop_duplicate.groupby('hotel')['is_canceled'].value_counts().unstack()
# Out:
# is_canceled       0      1
# hotel
# City Hotel    37377  16049
# Resort Hotel  25987   7976

# %%
dataframenew_drop_duplicate.groupby('hotel')['arrival_date_day_of_month'].mean()
# Out:
# hotel
# City Hotel      15.755082
# Resort Hotel    15.911050
# Name: arrival_date_day_of_month, dtype: float64

# %%
dataframenew_drop_duplicate.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
dataframenew_drop_duplicate.groupby(['hotel', 'arrival_date_month'])['adr'].mean().unstack()
# Out:
# arrival_date_month       April      August   December   February    January  \
# hotel
# City Hotel          117.156250  124.901601  92.717339  88.945304  85.092612
# Resort Hotel         79.283805  187.566659  65.425827  54.088764  49.131584
#
# arrival_date_month        July        June      March         May   November  \
# hotel
# City Hotel          120.055385  123.836342  94.763375  127.847147  89.454120
# Resort Hotel        156.159300  112.340141  57.569213   80.551101  48.835451
#
# arrival_date_month     October   September
# hotel
# City Hotel          107.304166  118.549054
# Resort Hotel         63.676313  100.892331

# %%
dataframenew_drop_duplicate.groupby('hotel')['adr'].mean()
# Out:
# hotel
# City Hotel      110.985270
# Resort Hotel     99.030296
# Name: adr, dtype: float64

# %%
df_colom
# Out:
#                         nama kolom
# 0                            hotel
# 1                      is_canceled
# 2                        lead_time
# 3                arrival_date_year
# 4               arrival_date_month
# 5         arrival_date_week_number
# 6        arrival_date_day_of_month
# 7          stays_in_weekend_nights
# 8             stays_in_week_nights
# 9                           adults
# 10                        children
# 11                          babies
# 12                            meal
# 13                         country
# 14                  market_segment
# 15            distribution_channel
# 16               is_repeated_guest
# 17          previous_cancellations
# 18  previous_bookings_not_canceled
# 19              reserved_room_type
# 20              assigned_room_type
# 21                 booking_changes
# 22                    deposit_type
# 23                           agent
# 24                         company
# 25            days_in_waiting_list
# ...

# %%
dataframenew_drop_duplicate.groupby('stays_in_weekend_nights')['stays_in_week_nights'].value_counts().unstack()
# Out:
# stays_in_week_nights         0        1       2       3       4       5   \
# stays_in_weekend_nights
# 0                         651.0  13216.0  9604.0  7456.0  3495.0   724.0
# 1                        3961.0   4580.0  5993.0  4933.0  2148.0  1040.0
# 2                        1561.0   4390.0  5147.0  3870.0  2231.0  7527.0
# 3                           NaN      NaN     NaN     NaN     NaN   284.0
# 4                           NaN      NaN     NaN     NaN     NaN    88.0
# 5                           NaN      NaN     NaN     NaN     NaN     NaN
# 6                           NaN      NaN     NaN     NaN     NaN     NaN
# 7                           NaN      NaN     NaN     NaN     NaN     NaN
# 8                           NaN      NaN     NaN     NaN     NaN     NaN
# 9                           NaN      NaN     NaN     NaN     NaN     NaN
# 10                          NaN      NaN     NaN     NaN     NaN     NaN
# ...

# %%
dataframenew_drop_duplicate.groupby(['hotel', 'stays_in_week_nights'])['adr'].mean().unstack()
# Out:
# stays_in_week_nights         0           1           2           3   \
# hotel
# City Hotel            99.829096  110.969261  111.633150  113.175246
# Resort Hotel          70.754539   82.337259   99.714237  107.197292
#
# stays_in_week_nights          4           5           6           7   \
# hotel
# City Hotel            111.439149  113.147481  113.450864  111.461192
# Resort Hotel          120.191532  109.246854  115.615873  106.774432
#
# stays_in_week_nights          8           9   ...    26       30     32   33  \
# hotel                                         ...
# City Hotel            109.572129  112.723333  ...   NaN   0.0000    NaN  NaN
# Resort Hotel          111.560961  117.118067  ...  0.26  32.1675  42.11  0.0
#
# stays_in_week_nights   34   35      40    41     42     50
# hotel
# City Hotel            0.0  0.0     NaN  8.34    NaN    NaN
# Resort Hotel          NaN  NaN  27.145   NaN  110.5  110.0
#
# [2 rows x 35 columns]

# %%
# .agg & .aggregate -> menerapkan satu atau lebih operasi statistik
dataframenew_drop_duplicate.groupby('customer_type')['lead_time'].agg(['min', 'max', 'mean', 'count'])
# Out:
#                  min  max        mean  count
# customer_type
# Contract           0  532  109.225231   3139
# Group              0  468   51.584559    544
# Transient          0  737   73.431274  71982
# Transient-Party    0  542  113.057489  11724

# %% [markdown]
# ### feature engineering

# %%
dataframenew_drop_duplicate['total_nights'] = dataframenew_drop_duplicate['stays_in_weekend_nights'] + dataframenew_drop_duplicate['stays_in_week_nights']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_33552\3684095449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframenew_drop_duplicate['total_nights'] = dataframenew_drop_duplicate['stays_in_weekend_nights'] + dataframenew_drop_duplicate['stays_in_week_nights']

# %%
dataframenew_drop_duplicate[['total_nights', 'stays_in_weekend_nights', 'stays_in_week_nights']].sample(5)
# Out:
#        total_nights  stays_in_weekend_nights  stays_in_week_nights
# 9722              3                        0                     3
# 16958             2                        0                     2
# 89375             6                        2                     4
# 92311             5                        1                     4
# 98269             7                        2                     5

# %%
df_colom = pd.DataFrame(dataframenew_drop_duplicate.columns, columns=['kolom'])

# %%
df_colom
# Out:
#                              kolom
# 0                            hotel
# 1                      is_canceled
# 2                        lead_time
# 3                arrival_date_year
# 4               arrival_date_month
# 5         arrival_date_week_number
# 6        arrival_date_day_of_month
# 7          stays_in_weekend_nights
# 8             stays_in_week_nights
# 9                           adults
# 10                        children
# 11                          babies
# 12                            meal
# 13                         country
# 14                  market_segment
# 15            distribution_channel
# 16               is_repeated_guest
# 17          previous_cancellations
# 18  previous_bookings_not_canceled
# 19              reserved_room_type
# 20              assigned_room_type
# 21                 booking_changes
# 22                    deposit_type
# 23                           agent
# 24            days_in_waiting_list
# 25                   customer_type
# ...

# %%
dataframenew_drop_duplicate['total_customer'] = dataframenew_drop_duplicate['children'] + dataframenew_drop_duplicate['adults'] + dataframenew_drop_duplicate['babies']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_33552\1738213321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframenew_drop_duplicate['total_customer'] = dataframenew_drop_duplicate['children'] + dataframenew_drop_duplicate['adults'] + dataframenew_drop_duplicate['babies']

# %%
# .apply(param) -> berfungsi untuk menempatkan function, param == disitu letak function
dataframenew_drop_duplicate['is_repeated_guest_category']  = dataframenew_drop_duplicate['is_repeated_guest'].apply(lambda x: 'YES' if x == 1 else 'NO')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_33552\2901137990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframenew_drop_duplicate['is_repeated_guest_category']  = dataframenew_drop_duplicate['is_repeated_guest'].apply(lambda x: 'YES' if x == 1 else 'NO')

# %%
dataframenew_drop_duplicate[['is_repeated_guest_category', 'is_repeated_guest']].sample(5)
# Out:
#        is_repeated_guest_category  is_repeated_guest
# 100268                         NO                  0
# 118160                         NO                  0
# 15778                          NO                  0
# 43281                          NO                  0
# 37581                          NO                  0

# %%
dataframenew_drop_duplicate['reservation_status_date']
# Out:
# 0         2015-07-01
# 1         2015-07-01
# 2         2015-07-02
# 3         2015-07-02
# 4         2015-07-03
#              ...
# 119385    2017-09-06
# 119386    2017-09-07
# 119387    2017-09-07
# 119388    2017-09-07
# 119389    2017-09-07
# Name: reservation_status_date, Length: 87389, dtype: object

# %%
# .map()
# boolean -> lambda
# multiclass -> .map()
month_mapping = {
    'January':1,
    'February':2,
    'March':3,
    'April':4,
    'May':5,
    'June':6,
    'July':7,
    'August':8,
    'September':9,
    'October':10,
    'Novemeber':11,
    'December':12
}

dataframenew_drop_duplicate['arrival_date_month'] = dataframenew_drop_duplicate['arrival_date_month'].map(month_mapping)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_33552\2888794339.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframenew_drop_duplicate['arrival_date_month'] = dataframenew_drop_duplicate['arrival_date_month'].map(month_mapping)

# %%
dataframenew_drop_duplicate['arrival_date_month']
# Out:
# 0         7.0
# 1         7.0
# 2         7.0
# 3         7.0
# 4         7.0
#          ...
# 119385    8.0
# 119386    8.0
# 119387    8.0
# 119388    8.0
# 119389    8.0
# Name: arrival_date_month, Length: 87389, dtype: float64

# %%
#mengubah tipedata object/string menjadi tipedata date & time
dataframenew_drop_duplicate['reservation_status_date'] = pd.to_datetime(dataframenew_drop_duplicate['reservation_status_date'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_33552\2922725214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframenew_drop_duplicate['reservation_status_date'] = pd.to_datetime(dataframenew_drop_duplicate['reservation_status_date'])

# %%
dataframenew_drop_duplicate['reservation_status_date']
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 87389, dtype: datetime64[ns]

# %% [markdown]
# # Advanced Data Preprocessing

# %%
dataframenew_drop_duplicate.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                       float64
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %% [markdown]
# ### interquartile range

# %%
numerik_colm = dataframenew_drop_duplicate.select_dtypes(include=['int64', 'float64']).columns.to_list()

# %%
# function remove_outliers_iqr = berfungsi untuk memisahkan outliers dari data mean
def remove_outliers_iqr(df, columns, x):
    df_clean = df.copy()
    for col in columns:
        q1 = df_clean[col].quantile(0.25)
        q3 = df_clean[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - x * iqr # 1.5
        upper_bound = q3 + x * iqr # 1.5
        df_clean = df_clean[(df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)]
    return df_clean

# %%
df_no_outliar = remove_outliers_iqr(dataframenew_drop_duplicate, numerik_colm, 1.5)
print(df_no_outliar)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# ...              ...          ...        ...                ...
# 119381    City Hotel            0        188               2017
# 119383    City Hotel            0        164               2017
# 119384    City Hotel            0         21               2017
# 119385    City Hotel            0         23               2017
# 119388    City Hotel            0        109               2017
#
#         arrival_date_month  arrival_date_week_number  \
# 4                      7.0                        27
# 6                      7.0                        27
# ...

# %%
df_no_outliar
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# ...              ...          ...        ...                ...
# 119381    City Hotel            0        188               2017
# 119383    City Hotel            0        164               2017
# 119384    City Hotel            0         21               2017
# 119385    City Hotel            0         23               2017
# 119388    City Hotel            0        109               2017
#
#         arrival_date_month  arrival_date_week_number  \
# 4                      7.0                        27
# 6                      7.0                        27
# ...

# %% [markdown]
# ## mix max scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_scaling = df_no_outliar.copy()
df_scaling_outlier = dataframenew_drop_duplicate.copy()

# %%
min_max_scale = MinMaxScaler()

# %% [markdown]
# method .fit_transform pada libary sklearn.preprocessing = Menghitung parameter yang diperlukan dan menerapkan transformasi pada data yang sudah dihitung.

# %%
df_scaling_outlier[numerik_colm] = min_max_scale.fit_transform(dataframenew_drop_duplicate[numerik_colm])

# %%
df_scaling[numerik_colm] = min_max_scale.fit_transform(df_no_outliar[numerik_colm])

# %%
df_scaling
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel          0.0   0.047297                0.0
# 6       Resort Hotel          0.0   0.000000                0.0
# 7       Resort Hotel          0.0   0.030405                0.0
# 8       Resort Hotel          1.0   0.287162                0.0
# 9       Resort Hotel          1.0   0.253378                0.0
# ...              ...          ...        ...                ...
# 119381    City Hotel          0.0   0.635135                1.0
# 119383    City Hotel          0.0   0.554054                1.0
# 119384    City Hotel          0.0   0.070946                1.0
# 119385    City Hotel          0.0   0.077703                1.0
# 119388    City Hotel          0.0   0.368243                1.0
#
#         arrival_date_month  arrival_date_week_number  \
# 4                 0.545455                  0.500000
# 6                 0.545455                  0.500000
# ...

# %% [markdown]
# ### standard scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scaled = StandardScaler()

# %%
df_std = df_no_outliar.copy()

# %%
df_std[numerik_colm] = std_scaled.fit_transform(df_no_outliar[numerik_colm])

# %%
df_std
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel    -0.675649  -0.876340          -1.830374
# 6       Resort Hotel    -0.675649  -1.072331          -1.830374
# 7       Resort Hotel    -0.675649  -0.946337          -1.830374
# 8       Resort Hotel     1.480059   0.117614          -1.830374
# 9       Resort Hotel     1.480059  -0.022380          -1.830374
# ...              ...          ...        ...                ...
# 119381    City Hotel    -0.675649   1.559548           1.107233
# 119383    City Hotel    -0.675649   1.223563           1.107233
# 119384    City Hotel    -0.675649  -0.778345           1.107233
# 119385    City Hotel    -0.675649  -0.750346           1.107233
# 119388    City Hotel    -0.675649   0.453598           1.107233
#
#         arrival_date_month  arrival_date_week_number  \
# 4                 0.304003                  0.138818
# 6                 0.304003                  0.138818
# ...

# %% [markdown]
# ### robust scaling

# %%
from sklearn.preprocessing import RobustScaler

# %%
df_robust = dataframenew_drop_duplicate.copy()

# %%
m_robust = RobustScaler()

# %%
df_robust[numerik_colm] = m_robust.fit_transform(dataframenew_drop_duplicate[numerik_colm])

# %%
df_robust.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  arrival_date_month  \
# count  87389.000000  87389.000000       87389.000000        82396.000000
# mean       0.274920      0.271028           0.210313            0.050339
# min        0.000000     -0.429825          -1.000000           -1.250000
# 25%        0.000000     -0.333333           0.000000           -0.500000
# 50%        0.000000      0.000000           0.000000            0.000000
# 75%        1.000000      0.666667           1.000000            0.500000
# max        1.000000      6.035088           1.000000            1.500000
# std        0.446477      0.754853           0.686094            0.744158
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87389.000000               87389.000000
# mean                  -0.007726                  -0.012287
# min                   -1.238095                  -1.000000
# 25%                   -0.523810                  -0.533333
# ...

# %%
# .corr()
df_no_outliar[numerik_colm].corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.159569           0.110126
# lead_time                          0.159569   1.000000           0.142712
# arrival_date_year                  0.110126   0.142712           1.000000
# arrival_date_month                -0.004275   0.129894          -0.484982
# arrival_date_week_number          -0.005631   0.126013          -0.501536
# arrival_date_day_of_month          0.012524   0.019577          -0.021237
# stays_in_weekend_nights            0.006174   0.188629          -0.009743
# stays_in_week_nights               0.046278   0.303182           0.000523
# adults                                  NaN        NaN                NaN
# children                                NaN        NaN                NaN
# babies                                  NaN        NaN                NaN
# is_repeated_guest                       NaN        NaN                NaN
# ...

# %%
dataframenew_drop_duplicate
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#         arrival_date_month  arrival_date_week_number  \
# 0                      7.0                        27
# 1                      7.0                        27
# ...
